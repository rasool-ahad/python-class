# %% [markdown]
# # introduction to python

# %% [markdown]
# * [programming languages](#programming-languages)
# * [compiler vs interpreter](#compiler-vs-interpreter)
# * [jupyter notebook](#jupyter-notebook)
# * [pip and conda](#pip-and-conda)

# %% [markdown]
# ## programming languages :
#
# * #### high-level languages :
#         easy for human like : python, javascript
# * #### middle-level :
#         like c, c++, java
# * #### low-level languages :
#         easy for machine like : assembley

# %% [markdown]
# ## compiler vs interpreter :
# * #### compiler :
# a compiler translates the entire source code in a single run. An interpreter translates the entire source code line by line
# like c++, c, FLATTEN
#     * advantages of compilers:
#     the program code is already translated into machine code. thus, it code execuation time is less
#     * disadvantage of compilers :
#     you can not change the program without going back to the source code
#
# * #### interpreter :
# An interpreter is a program that executes the programming code directly instead of just translating it into another format. It translates and executes programming language statements one by one.
# like python, js
#     * advantage: easer to use and debugging
#     * disadvantage : execuation tome is more

# %% [markdown]
# ![compiler-vs-interpreter.PNG](attachment:a0807d6c-b94a-4f28-84fa-be11ce17cd6f.PNG)

# %% [markdown]
# why code below rise an error ?

# %%
# code :
power2(2)
def power2(x):
    return x**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # code :
# ----> 2 power2(2)
#       3 def power2(x):
#       4     return x**2
#
# NameError: name 'power2' is not defined

# %% [markdown]
# fix the error :

# %%
#code :

def power2(x):
    return x**2
power2(2)
# Out:
# 4

# %% [markdown]
# ## jupyter

# %% [markdown]
# Jupyter is the latest web-based interactive development environment for notebooks, code, and data.

# %% [markdown]
# useful tools in jupyter are :
# * jupyter notebook
# * jupyte lab :JupyterLab is a next-generation web-based user interface for Project Jupyter.

# %% [markdown]
#     you can start jupyter lab and jupyter notebook with code below in conda terminal  :
#     jupyter notebook
#     jupyter lab

# %% [markdown]
# ### pip and conda
# If you’re using Python in the world of data science or scientific computing, you will soon discover that Python has two different packaging systems: pip and Conda. Which raises some questions:
#
# * How are they different?
# * What are the tradeoffs between the two?
# * Which should you use?
# * The fundamental difference between pip and Conda packaging is what they put in packages.
#
# **Pip packages are Python libraries like NumPy or matplotlib. Conda packages include Python libraries (NumPy or matplotlib), C libraries (libjpeg), and executables (like C compilers, and even the Python interpreter itself).**

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
