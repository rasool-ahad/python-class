# %% [markdown]
# # algorithm excercis

# %% [markdown]
# 1-  **HOW TO CROSS THE RIVER?**
# A farmer with a fox, a goose, and a sack of corn needs to cross a river. The farmer
# has a rowboat, but there is room for only the farmer and one of his three items. Unfortunately,
# both the fox and the goose are hungry. The fox cannot be left alone with the
# goose, or the fox will eat the goose. Likewise, the goose cannot be left alone with the
# sack of corn, or the goose will eat the corn. How does the farmer get everything
# across the river?

# %% [markdown]
# ![excercise-02-01.PNG](attachment:3fdaa10b-a5a4-48b1-a0e4-aef81cb61b53.PNG)

# %% [markdown]
# 2- **THE SLIDING EIGHT** :A 3×3 grid is filled with eight tiles, numbered 1 through 8, and one empty space. Initially,
# the grid is in a jumbled configuration. A tile can be slid into an adjacent empty
# space, leaving the tile’s previous location empty. The goal is to slide the tiles to place
# the grid in an ordered configuration, from tile 1 in the upper left.

# %% [markdown]
# ![excercise-02-02.PNG](attachment:f9c9c5b7-6913-4e0b-9822-bedd85fe0d7a.PNG)

# %% [markdown]
# 3- **COMPLETING A SUDOKU SQUARE**:
# A 9×9 grid is partially filled with single digits (from 1–9), and the player must fill in
# the empty squares while meeting certain constraints: In each row and column, each
# digit must appear exactly once, and further, in each marked 3×3 area, each digit
# must appear exactly once.

# %% [markdown]
# ![excercise-02-03.PNG](attachment:a28dc2c3-a78c-4b60-bf69-023efeccf26b.PNG)

# %% [markdown]
# answer this question about sudoku : how do you pick first empty square to fill ?? and how do you continue??
