# %% [markdown]
# ## python basics excersise

# %% [markdown]
# 1- write a program that take n as input and print out multipication table from 1 to n

# %% [markdown]
# example :

# %% [markdown]
# input :
# ![excercise-1-01.PNG](attachment:ed92750c-28ef-427e-b3d7-69ad9a38eced.PNG)

# %% [markdown]
# <hr>

# %% [markdown]
# 2- In mathematics, Pascal's triangle is a triangular array of the binomial coefficients that arises in probability theory, combinatorics, and algebra. In much of the Western world, it is named after the French mathematician Blaise Pascal, although other mathematicians studied it centuries before him in India, Persia, China, Germany, and Italy.
#
# The rows of Pascal's triangle are conventionally enumerated starting with row {\displaystyle n=0}n=0 at the top (the 0th row). The entries in each row are numbered from the left beginning with {\displaystyle k=0}k=0 and are usually staggered relative to the numbers in the adjacent rows. The triangle may be constructed in the following manner: In row 0 (the topmost row), there is a unique nonzero entry 1. Each entry of each subsequent row is constructed by adding the number above and to the left with the number above and to the right, treating blank entries as 0. For example, the initial number in the first (or any other) row is 1 (the sum of 0 and 1), whereas the numbers 1 and 3 in the third row are added to produce the number 4 in the fourth row.

# %% [markdown]
# ![excercise-1-02.PNG](attachment:b5fd5555-da10-479d-af00-1440ca63e691.PNG)

# %% [markdown]
# write a program that takes n from user and print first n row of Paskal`s triangle

# %% [markdown]
# ![excercise-1-03.PNG](attachment:c0a344b1-a04e-4650-9df0-1c605dcd1085.PNG)

# %% [markdown]
# <hr>

# %% [markdown]
# 3- Akbar as a author. he writes many texts every day.in last 3 day he found out he make a bad mistake. he press `=` instead of `Backspace` for deleteing a character.
# write a program to help akbar to get original text from written texts.

# %% [markdown]
# input example:

# %%
"رسوی=ل ض=احدسس==ی"
# Out:
# 'رسوی=ل ض=احدسس==ی'

# %% [markdown]
# output example :

# %%
"رسول احدی"
# Out:
# 'رسول احدی'

# %% [markdown]
# <hr>

# %% [markdown]
# 4- Given a string and a string dictionary, find the longest string in the dictionary that can be formed by deleting some characters of the given string. If there are more than one possible results, return the longest word with the smallest lexicographical order. If there is no possible result, return the empty string.

# %% [markdown]
# example 1 :
# ```
# Input: d = {"ale", "apple", "monkey", "plea"}
#        S = "abpcplea"
# Output: "apple"
# Explanation: After deleting "b", "c"
# "a" S became "apple" which is present
# in d.
# ```

# %% [markdown]
# example 2 :
# ```
# Input: d = {"a", "b", "c"}
#        S = "abpcplea"
# Output: "a"
# Explanation: After deleting "b", "p"
# "c", "p", "l", "e", "a" S became
# "a" which is present in d.
# ```
